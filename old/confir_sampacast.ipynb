# %%
import time
import pandas as pd
from datetime import date, datetime
from urllib.parse import quote
import webbrowser
import openpyxl

# %%
def generate_whatsapp_link(phone_number, message):
    phone_number = ''.join(filter(str.isdigit, str(phone_number)))
    
    encoded_message = quote(message)
    return f"https://wa.me/55{phone_number}/?text={encoded_message}"

def send_whatsapp_message(phone_number, message):
    whatsapp_link = generate_whatsapp_link(phone_number, message)
    print(f"Abrindo aba para: {phone_number}")
    webbrowser.open(whatsapp_link)
    time.sleep(2)

def send_messages_from_excel(file_path):
    try:
        df = pd.read_excel(file_path)
        for index, row in df.iterrows():
            name = str(row['Usuário - Nome']).split()[0].title()
            phone_number = str(row['Usuário - Telefone'])
            unid = str(row['Unidade'])
            
            if isinstance(row['Horário Início'], str):
                hora = datetime.strptime(row['Horário Início'], '%H:%M:%S')
                horario = hora.strftime('%H:%M')
            else:
                horario = row['Horário Início'].strftime('%H:%M')

            message = (f"Olá, {name}! Bom dia!\n\n"
                    f"Nós da ADE SAMPA entramos em contato para confirmar sua agenda para amanhã às *{horario}* na unidade *{unid}*.\n\n"
                    "*Precisa cancelar?*\n"
                    "É obrigatório acessar o sistema e realizar o cancelamento manualmente. O não comparecimento sem cancelamento prévio gera penalidades.\n\n"
                    "É fundamental que você conheça nosso manual de conduta. Acesse aqui: https://adesampa.com.br/wp-content/uploads/2025/11/Manual-de-conduta-unificado.pdf \n\n"
                    "Agradecemos a atenção e até amanhã!")
            send_whatsapp_message(phone_number, message)

    except Exception as e:
        print(f"Ocorreu um erro ao processar o arquivo Excel: {e}")

if __name__ == "__main__":
    file_path = r'agenda.xlsx'
    send_messages_from_excel(file_path)
# Out:
# Abrindo aba para: (11)98148-4882
# Gtk-Message: 12:17:16.748: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
# [15552, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:15552): Gtk-WARNING **: 12:17:16.793: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:16.793: Failed to load module "canberra-gtk-module"
# [15552, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:15552): Gtk-WARNING **: 12:17:16.794: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:16.794: Failed to load module "canberra-gtk-module"
# Abrindo aba para: (11)94161-5102
# Gtk-Message: 12:17:18.711: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
# [15727, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:15727): Gtk-WARNING **: 12:17:18.756: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:18.756: Failed to load module "canberra-gtk-module"
# [15727, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:15727): Gtk-WARNING **: 12:17:18.758: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:18.758: Failed to load module "canberra-gtk-module"
# Abrindo aba para: (11)99205-0441
# Gtk-Message: 12:17:20.778: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
# [15898, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:15898): Gtk-WARNING **: 12:17:20.838: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:20.838: Failed to load module "canberra-gtk-module"
# [15898, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:15898): Gtk-WARNING **: 12:17:20.839: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:20.839: Failed to load module "canberra-gtk-module"
# Abrindo aba para: (11)95970-0099
# Gtk-Message: 12:17:22.789: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
# [16070, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:16070): Gtk-WARNING **: 12:17:22.844: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:22.844: Failed to load module "canberra-gtk-module"
# [16070, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:16070): Gtk-WARNING **: 12:17:22.845: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:17:22.845: Failed to load module "canberra-gtk-module"
# Abrindo aba para: (11)94918-4942
# Gtk-Message: 12:17:24.817: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
# [16245, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox
GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:18:16.927: Failed to load module "canberra-gtk-module"
# Abrindo aba para: (11)97783-6980
# Gtk-Message: 12:18:18.853: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
# [19905, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:19905): Gtk-WARNING **: 12:18:18.921: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:18:18.921: Failed to load module "canberra-gtk-module"
# [19905, Main Thread] WARNING: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.: 'glib warning', file /build/firefox/parts/firefox/build/toolkit/xre/nsSigHandlers.cpp:201
#
# (firefox_firefox:19905): Gtk-WARNING **: 12:18:18.922: GTK+ module /snap/firefox/7766/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 12:18:18.922: Failed to load module "canberra-gtk-module"

# %%
def generate_whatsapp_link(phone_number, message):
    phone_number = ''.join(filter(str.isdigit, str(phone_number)))
    
    encoded_message = quote(message)
    return f"https://wa.me/55{phone_number}/?text={encoded_message}"

def send_whatsapp_message(phone_number, message):
    whatsapp_link = generate_whatsapp_link(phone_number, message)
    print(f"Abrindo aba para: {phone_number}")
    edge_path = r'"C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe" %s'
    webbrowser.get(edge_path).open(whatsapp_link)    
    time.sleep(0.5)

def send_messages_from_excel(file_path):
    try:
        df = pd.read_excel(file_path)
        for index, row in df.iterrows():
            name = str(row['Usuário - Nome']).split()[0].title()
            phone_number = str(row['Usuário - Telefone'])
            unid = str(row['Unidade'])
            
            if isinstance(row['Horário Início'], str):
                hora = datetime.strptime(row['Horário Início'], '%H:%M:%S')
                horario = hora.strftime('%H:%M')
            else:
                horario = row['Horário Início'].strftime('%H:%M')

            message = (f"Olá, {name}! Bom dia!\n\n"
                    f"Nós da ADE SAMPA entramos em contato para confirmar sua agenda para Segunda-Feira às *{horario}* na unidade *{unid}*.\n\n"
                    "*Precisa cancelar?*\n"
                    "É obrigatório acessar o sistema e realizar o cancelamento manualmente. O não comparecimento sem cancelamento prévio gera penalidades.\n\n"
                    "É fundamental que você conheça nosso manual de conduta. Acesse aqui: https://adesampa.com.br/wp-content/uploads/2025/11/Manual-de-conduta-unificado.pdf \n\n"
                    "Agradecemos a atenção e até amanhã!")
            send_whatsapp_message(phone_number, message)

    except Exception as e:
        print(f"Ocorreu um erro ao processar o arquivo Excel: {e}")

if __name__ == "__main__":
    file_path = r'agenda.xlsx'
    send_messages_from_excel(file_path)
# Out:
# Abrindo aba para: (11)98968-6050
# Abrindo aba para: (11)99558-8005
# Abrindo aba para: (11)94377-8855
# Abrindo aba para: (11)97588-9546
# Abrindo aba para: (11)94030-8379
# Abrindo aba para: (11)98148-4882
# Abrindo aba para: (11)98693-6733
# Abrindo aba para: (11)94747-4646
# Abrindo aba para: (11)95942-0815
# Abrindo aba para: (11)99891-7390
# Abrindo aba para: (21)97545-4329
# Abrindo aba para: (11)98710-6292
# Abrindo aba para: (11)99716-8193
# Abrindo aba para: (11)95771-0747
# Abrindo aba para: (11)99146-5220
# Abrindo aba para: (11)95289-9351
# Abrindo aba para: (11)99891-7390
# Abrindo aba para: (11)95380-6984
# Abrindo aba para: (11)97726-8620
# Abrindo aba para: (11)95772-1569
# Abrindo aba para: (11)99984-2390
# Abrindo aba para: (11)97314-1704
# Abrindo aba para: (11)97498-7994
# Abrindo aba para: (11)97488-7534
# Abrindo aba para: (11)94670-2510
# Abrindo aba para: (11)96847-5102
# Abrindo aba para: (11)95380-6984
